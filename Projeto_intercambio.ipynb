# %% [markdown]
# <a href="https://colab.research.google.com/github/Joabe18/Projeto-intercambio/blob/main/Projeto_intercambio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Requisitos

# %% [markdown]
# Requisitos:
#
# - -entender como as empresas brasileiras/multinacionais com presença nos dois paises.
# desenvolvimento sustentavel e se tem coerencia se tem coerencia do que ela faz e fala
#
# - Objetivo do projeto atual:
# Ferramentas de Ia vao ajudar a avaliar o projeto
# Qual foi sua expctativa antes e depois?
#
# Questoes:
# Qual é a sua expctativaa no projeto x avaliacao geral final do projeto.
#
# Criterios. pegar separadamente as planilhas brasilxportugal, e como eles avaliam o trabalho de equipe. (trabalho de equipe x gestao de tempo x comunicacao) - team works skill.
#
# trabalho de equipe com os profissinais brasileiros x com os estrangeiros e entre colegas.
#
# liderança (verifiquem se liderança foi mais ou menos desafiador aqui ou la, e se os alunos desenvolveram isso)
#
# competencias interculturais (parecido ou diferente)
#
# saber as dimensoes e variaveis:
#
# Questões para avaliacao
# - avaliacao de expectativas
# - expectativa antes do projeto PCI?
# - Avaliacao sobre o projeto
# - ex expectativa alta (5 numa esala de 1 a 5 x avaliacao finl (2 ou 3)
# - comparar resultados BR x PT
# - Trabalho em equipe
#
# Br (ipiranga)
# -> trabalho colegas brasileiros
# -> trabalho comelga porgueses
# PT(aveiro) obs: ver se n tem nenhuma distorção. estrangeiro=brasileiro?
# ->trabalho com colega
# ->colega estrangeiro
#
# Consciencia intercultural
#
# Para o ETL:
# - pode eliminar a competencia linguistica
# - ate a coluna 5 pode eleiminar.
# - Se fazer o pci aumenta a empregabilidade. Pci aumentou a retencao do aluno no curso
# - "explique a sua resposta". avaliar para detectar eventuais divergencias
# - "etapas, instruções e objetivos"
#
# - RESULTADO:
# pontos positivos e o que pode ser melhorado

# %% [markdown]
# # Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Tabelas

# %%
discentes_1s_2022 = pd.read_excel('/content/drive/MyDrive/PCI_Anonimizados/Anonimizados/1s2022 Discentes - Pesquisa de Percepção sobre o PCI da Cesu.xlsx')

# %%
discentes_1s_2023 = pd.read_excel('/content/drive/MyDrive/PCI_Anonimizados/Anonimizados/1s2023 Discentes - Pesquisa de Percepção sobre o PCI da Cesu.xlsx')

# %%
discentes_2s_2023_ipiranga = pd.read_excel('/content/drive/MyDrive/PCI_Anonimizados/Anonimizados/DISCENTES 2s2023 - Pesquisa de Percepção sobre o PCI da Cesu 2 - FATEC IPIRANGA.xlsx')

# %%
discentes_2s_2023_aveiro = pd.read_excel('/content/drive/MyDrive/PCI_Anonimizados/Anonimizados/DISCENTES 2s2023 - Pesquisa de Percepção sobre o PCI da Cesu 2 - AVEIRO.xlsx')

# %% [markdown]
# ## discentes_2s_2023_ipiranga

# %%
discentes_2s_2023_ipiranga.head()
# Out:
#        Hora de início   Hora de conclusão  \
# 0 2023-11-06 10:30:57 2023-11-06 10:37:58
# 1 2023-11-06 10:37:19 2023-11-06 10:42:27
# 2 2023-11-06 10:46:56 2023-11-06 10:53:49
# 3 2023-11-06 10:58:27 2023-11-06 11:18:10
# 4 2023-11-06 11:31:45 2023-11-06 11:42:48
#
#   O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?  \
# 0  Fatec São José do Rio Preto com Profª. Edilene...
# 1  Fatec São José do Rio Preto com Profª. Edilene...
# 2  Fatec São José do Rio Preto com Profª. Edilene...
# 3  Fatec São José do Rio Preto com Profª. Edilene...
# 4  Fatec São José do Rio Preto com Profª. Edilene...
#
#   Em qual período você estuda? Quantas vezes você já participou de um PCI?  \
# 0                        Manhã             Uma - este é o meu primeiro PCI
# 1                        Manhã             Uma - este é o meu primeiro PCI
# 2                        Manhã             Uma - este é o meu primeiro PCI
# ...

# %%
discentes_2s_2023_ipiranga.columns
# Out:
# Index(['Hora de início', 'Hora de conclusão',
#        'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?',
#        'Em qual período você estuda?',
#        'Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão Oral', 'Gramática',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI  aumenta as chances de sucesso no mercado de trabalho", eu',
#        'Quanto à afirmação "A experiência com o PCI aumenta meu interesse em permanecer no curso até a conclusão", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'As instruções sobre os procedimentos estavam claras.',
# ...

# %%
discentes_2s_2023_ipiranga['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'].value_counts()
# Out:
# O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?
# Fatec Ipiranga com Profª. Patricia Patrício e Universidade de Aveiro                                                57
# Fatec Sumaré com Profª Tessa Cristina Pereira Coltro e Prof. Tiago Rebecca e Symbiosis                              51
# Fatec Assis com Profª Luciana S. Tosseto Saloti, Profª Patricia Irina L. de Moraes e DUOC                           45
# Fatec Campinas com Profª Luciene Garbuio e Tianjin                                                                  41
# Fatec Guaratinguetá  com Profª. Regiane Camargo e Areandina                                                         35
# Fatec Americana com Prof. Carlos Augusto Amaral Moreira e Nassau                                                    29
# Fatec Garça com profª Leysiane Cristina Pavani Pazini e Setsunan University e National Chiayi University            28
# ...

# %%
discentes_2s_2023_ipiranga['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'] = discentes_2s_2023_ipiranga['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'].str.strip()

filtro_resultado = discentes_2s_2023_ipiranga['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'] == 'Fatec Ipiranga com Profª. Patricia Patrício e Universidade de Aveiro'

discentes_2s_2023_ipiranga_filtrado = discentes_2s_2023_ipiranga[filtro_resultado]

# %%
discentes_2s_2023_ipiranga_filtrado.head()
# Out:
#          Hora de início   Hora de conclusão  \
# 180 2023-11-24 16:05:45 2023-11-24 16:09:04
# 181 2023-11-24 16:27:35 2023-11-24 16:31:50
# 182 2023-11-24 17:12:39 2023-11-24 17:22:35
# 188 2023-11-25 13:39:20 2023-11-25 13:59:19
# 190 2023-11-25 20:56:40 2023-11-25 21:04:56
#
#     O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?  \
# 180  Fatec Ipiranga com Profª. Patricia Patrício e ...
# 181  Fatec Ipiranga com Profª. Patricia Patrício e ...
# 182  Fatec Ipiranga com Profª. Patricia Patrício e ...
# 188  Fatec Ipiranga com Profª. Patricia Patrício e ...
# 190  Fatec Ipiranga com Profª. Patricia Patrício e ...
#
#     Em qual período você estuda? Quantas vezes você já participou de um PCI?  \
# 180                        Manhã                                        Duas
# 181                        Noite             Uma - este é o meu primeiro PCI
# 182                        Manhã                                        Duas
# ...

# %%
discentes_2s_2023_ipiranga_filtrado.columns
# Out:
# Index(['Hora de início', 'Hora de conclusão',
#        'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?',
#        'Em qual período você estuda?',
#        'Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão Oral', 'Gramática',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI  aumenta as chances de sucesso no mercado de trabalho", eu',
#        'Quanto à afirmação "A experiência com o PCI aumenta meu interesse em permanecer no curso até a conclusão", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'As instruções sobre os procedimentos estavam claras.',
# ...

# %%
colunas_para_remover = [coluna for coluna in discentes_2s_2023_ipiranga_filtrado.columns if coluna.startswith('Termo de consentimento')]
discentes_2s_2023_ipiranga_filtrado.drop(columns=colunas_para_remover, inplace=True)
# Out:
# <ipython-input-12-dac64947c7d5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   discentes_2s_2023_ipiranga_filtrado.drop(columns=colunas_para_remover, inplace=True)

# %%
# , 'Faça uma autoavaliação do seu desempenho no projeto.'
colunas_para_remover = ['Hora de início', 'Hora de conclusão', 'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?', 'Em qual período você estuda?', 'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita', 'Leitura', 'Compreensão Oral', 'Gramática', 'As instruções sobre os procedimentos estavam claras.', 'As etapas de organização do projeto estavam adequadas.', 'Os objetivos do projeto estavam claros.', 'O tempo para a realização das tarefas foi suficiente.', 'O grupo estrangeiro tinha as mesmas informações que o grupo brasileiro.', 'O(a) professor(a) dedicou tempo de aula para a resolução de dúvidas.', 'O(a) professor(a) ofereceu ajuda para resolver questões relativas aos PCIs.', 'Quais ferramentas você utilizou para a realização do PCI? (Marque todas as que você utilizou para se comunicar com as equipes e realizar as tarefas propostas)']
discentes_2s_2023_ipiranga_filtrado.drop(columns=colunas_para_remover, inplace=True)
# Out:
# <ipython-input-13-116eef12fe6c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   discentes_2s_2023_ipiranga_filtrado.drop(columns=colunas_para_remover, inplace=True)

# %%
discentes_2s_2023_ipiranga_filtrado.columns
# Out:
# Index(['Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI  aumenta as chances de sucesso no mercado de trabalho", eu',
#        'Quanto à afirmação "A experiência com o PCI aumenta meu interesse em permanecer no curso até a conclusão", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'Você se dedicou à realização das tarefas do PCI.',
#        'O grupo brasileiro se dedicou à realização das tarefas do PCI.',
#        'O grupo estrangeiro se dedicou à realização das tarefas do PCI.',
#        'Você buscou interagir com o grupo brasileiro.',
#        'Você buscou interagir com o grupo estrangeiro.',
# ...

# %%
discentes_2s_2023_ipiranga_filtrado.head()
# Out:
#     Quantas vezes você já participou de um PCI?  \
# 180                                        Duas
# 181             Uma - este é o meu primeiro PCI
# 182                                        Duas
# 188                                        Duas
# 190                                        Duas
#
#     Recomendaria aos seus colegas participar em um PCI.  \
# 180                                Concordo totalmente
# 181                                Concordo totalmente
# 182                              Concordo parcialmente
# 188                                Concordo totalmente
# 190                                Concordo totalmente
#
#     Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro  \
# 180                                     Melhorou muito
# 181                                     Melhorou muito
# 182                                   Foi em português
# 188                                     Melhorou muito
# ...

# %%
plt.style.use('ggplot')

# %% [markdown]
# Quantas vezes você já participou de um PCI

# %%
sns.countplot(x='Quantas vezes você já participou de um PCI?',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('Quantidade de vezes que participou de um PCI')
plt.xlabel('Quantidade')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Quantas vezes você já participou de um PCI?'].value_counts()
# Out:
# Quantas vezes você já participou de um PCI?
# Uma - este é o meu primeiro PCI    38
# Duas                               18
# Três ou mais vezes                  1
# Name: count, dtype: int64

# %% [markdown]
# Recomendaria aos seus colegas participar em um PCI

# %%
sns.countplot(x='Recomendaria aos seus colegas participar em um PCI.',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('Recomendaria aos colegas participar em um PCI')
plt.xlabel('Recomendaria')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Recomendaria aos seus colegas participar em um PCI.'].value_counts()
# Out:
# Recomendaria aos seus colegas participar em um PCI.
# Concordo totalmente          37
# Concordo parcialmente        18
# Não concordo nem discordo     2
# Name: count, dtype: int64

# %% [markdown]
# Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro

# %%
sns.countplot(x='Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro')
plt.xlabel('Recomendaria')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro'].value_counts()
# Out:
# Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro
# Foi em português     31
# Melhorou um pouco    11
# Ficou igual           9
# Melhorou muito        6
# Name: count, dtype: int64

# %% [markdown]
# Quanto à afirmação "A experiência com o PCI  aumenta as chances de sucesso no mercado de trabalho", eu

# %% [markdown]
# Retirei as aspas das colunas manualmente usando Excel

# %%
pip install XlsxWriter

# %%
# Seu DataFrame (substitua pelo seu DataFrame real)
df = discentes_2s_2023_ipiranga_filtrado

# Caminho para o arquivo Excel
caminho_arquivo = "discentes_2s_2023_ipiranga_filtrado.xlsx"

# Exporte o DataFrame para o arquivo Excel
df.to_excel(caminho_arquivo, index=False)

# %%
discentes_2s_2023_ipiranga_filtrado = pd.read_excel('/content/drive/MyDrive/PCI_Anonimizados/Anonimizados/discentes_2s_2023_ipiranga_filtrado.xlsx')

# %%
discentes_2s_2023_ipiranga_filtrado.columns
# Out:
# Index(['Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Chances no mercado de trabalho aumentaram',
#        'PCI aumentou interesse em permanecer no curso até a conclusão',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'Você se dedicou à realização das tarefas do PCI.',
#        'O grupo brasileiro se dedicou à realização das tarefas do PCI.',
#        'O grupo estrangeiro se dedicou à realização das tarefas do PCI.',
#        'Você buscou interagir com o grupo brasileiro.',
#        'Você buscou interagir com o grupo estrangeiro.',
#        'Em termos de expectativa, o que você esperava antes do início do PCI. Assinale as alternativas que correspondem à sua percepção.',
# ...

# %%
sns.countplot(x='Chances no mercado de trabalho aumentaram',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('Chances no mercado de trabalho aumentaram')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Chances no mercado de trabalho aumentaram'].value_counts()
# Out:
# Chances no mercado de trabalho aumentaram
# Concordo totalmente          22
# Concordo parcialmente        22
# Não concordo nem discordo    13
# Name: count, dtype: int64

# %% [markdown]
# PCI aumentou interesse em permanecer no curso até a conclusão

# %%
sns.countplot(x='PCI aumentou interesse em permanecer no curso até a conclusão',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('PCI aumentou interesse em permanecer no curso até a conclusão')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['PCI aumentou interesse em permanecer no curso até a conclusão'].value_counts()
# Out:
# PCI aumentou interesse em permanecer no curso até a conclusão
# Concordo totalmente          25
# Não concordo nem discordo    16
# Concordo parcialmente        14
# Discordo parcialmente         1
# Discordo totalmente           1
# Name: count, dtype: int64

# %% [markdown]
# Como foi sua interação com seus colegas do grupo brasileiro?

# %%
sns.countplot(x='Como foi sua interação com seus colegas do grupo brasileiro?',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('Interação com seus colegas do grupo brasileiro')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Como foi sua interação com seus colegas do grupo brasileiro?'].value_counts()
# Out:
# Como foi sua interação com seus colegas do grupo brasileiro?
# Ótima                      28
# Boa                        21
# Regular ou satisfatória     6
# Péssima                     2
# Name: count, dtype: int64

# %% [markdown]
# Como foi sua interação com seus colegas do grupo estrangeiro?

# %%
sns.countplot(x='Como foi sua interação com seus colegas do grupo estrangeiro?',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('Interação com seus colegas do grupo estrangeiro')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Como foi sua interação com seus colegas do grupo estrangeiro?'].value_counts()
# Out:
# Como foi sua interação com seus colegas do grupo estrangeiro?
# Boa                        24
# Ótima                      21
# Regular ou satisfatória     9
# Ruim                        2
# Péssima                     1
# Name: count, dtype: int64

# %%
discentes_2s_2023_ipiranga_filtrado.columns
# Out:
# Index(['Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Chances no mercado de trabalho aumentaram',
#        'PCI aumentou interesse em permanecer no curso até a conclusão',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'Você se dedicou à realização das tarefas do PCI.',
#        'O grupo brasileiro se dedicou à realização das tarefas do PCI.',
#        'O grupo estrangeiro se dedicou à realização das tarefas do PCI.',
#        'Você buscou interagir com o grupo brasileiro.',
#        'Você buscou interagir com o grupo estrangeiro.',
#        'Em termos de expectativa, o que você esperava antes do início do PCI. Assinale as alternativas que correspondem à sua percepção.',
# ...

# %% [markdown]
# Você se dedicou à realização das tarefas do PCI.

# %%
sns.countplot(x='Você se dedicou à realização das tarefas do PCI.',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('Se dedicou à realização das tarefas do PCI')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Você se dedicou à realização das tarefas do PCI.'].value_counts()
# Out:
# Você se dedicou à realização das tarefas do PCI.
# Concordo totalmente      45
# Concordo parcialmente    12
# Name: count, dtype: int64

# %% [markdown]
# O grupo brasileiro se dedicou à realização das tarefas do PCI.

# %%
sns.countplot(x='O grupo brasileiro se dedicou à realização das tarefas do PCI.',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('Grupo brasileiro se dedicou à realização das tarefas do PCI')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['O grupo brasileiro se dedicou à realização das tarefas do PCI.'].value_counts()
# Out:
# O grupo brasileiro se dedicou à realização das tarefas do PCI.
# Concordo totalmente          40
# Concordo parcialmente        14
# Não concordo nem discordo     2
# Discordo parcialmente         1
# Name: count, dtype: int64

# %% [markdown]
# O grupo estrangeiro  se dedicou à realização das tarefas do PCI.

# %%
sns.countplot(x='O grupo estrangeiro se dedicou à realização das tarefas do PCI.',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('Grupo estrangeiro se dedicou à realização das tarefas do PCI')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['O grupo estrangeiro se dedicou à realização das tarefas do PCI.'].value_counts()
# Out:
# O grupo estrangeiro se dedicou à realização das tarefas do PCI.
# Concordo totalmente          34
# Concordo parcialmente        16
# Discordo parcialmente         4
# Não concordo nem discordo     2
# Discordo totalmente           1
# Name: count, dtype: int64

# %% [markdown]
# Em termos de expectativa, o que você esperava antes do início do PCI. Assinale as alternativas que correspondem à sua percepção.

# %%
discentes_2s_2023_ipiranga_filtrado['Em termos de expectativa, o que você esperava antes do início do PCI. Assinale as alternativas que correspondem à sua percepção.'].value_counts()
# Out:
# Em termos de expectativa, o que você esperava antes do início do PCI. Assinale as alternativas que correspondem à sua percepção.
# Criar vínculos com colegas internacionais;                                                                                                                                                                    10
# Ter uma experiência de comunicação intercultural;                                                                                                                                                              7
# Criar vínculos com colegas internacionais;Ter uma experiência de comunicação intercultural;Ter maior compreensão da minha área/campo de estudo;                                                                7
# Nada em especial;                                                                                                                                                                                              6
# ...

# %% [markdown]
# Quanto à afirmação “Estava motivado a participar de um PCI antes de ter tido esta experiência”, eu

# %%
sns.countplot(x='Estava motivado a participar de um PCI antes de ter tido esta experiência',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('Estava motivado a participar de um PCI antes de ter tido esta experiência')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Estava motivado a participar de um PCI antes de ter tido esta experiência'].value_counts()
# Out:
# Estava motivado a participar de um PCI antes de ter tido esta experiência
# Concordo totalmente          25
# Concordo parcialmente        24
# Não concordo nem discordo     6
# Discordo totalmente           1
# Discordo parcialmente         1
# Name: count, dtype: int64

# %% [markdown]
# Em termos de trabalho em equipe com os brasileiros, a experiência foi satisfatória\n

# %%
sns.countplot(x='Em termos de trabalho em equipe com os brasileiros, a experiência foi satisfatória\n',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('trabalho em equipe com os brasileiros foi satisfatório')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Em termos de trabalho em equipe com os brasileiros, a experiência foi satisfatória\n'].value_counts()
# Out:
# Em termos de trabalho em equipe com os brasileiros, a experiência foi satisfatória\n
# Concordo totalmente          32
# Concordo parcialmente        21
# Discordo parcialmente         2
# Discordo totalmente           1
# Não concordo nem discordo     1
# Name: count, dtype: int64

# %% [markdown]
# Em termos de trabalho em equipe com os estrangeiros, a experiência foi satisfatória

# %%
sns.countplot(x='Em termos de trabalho em equipe com os estrangeiros, a experiência foi satisfatória',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('trabalho em equipe com os estrangeiros foi satisfatório')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Em termos de trabalho em equipe com os estrangeiros, a experiência foi satisfatória'].value_counts()
# Out:
# Em termos de trabalho em equipe com os estrangeiros, a experiência foi satisfatória
# Concordo totalmente          28
# Concordo parcialmente        21
# Não concordo nem discordo     5
# Discordo parcialmente         2
# Discordo totalmente           1
# Name: count, dtype: int64

# %% [markdown]
# Com relação ao trabalho em equipe, em que área você notou maior desenvolvimento?

# %%
sns.countplot(x='Com relação ao trabalho em equipe, em que área você notou maior desenvolvimento?',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('Maior desenvolvimento em')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Com relação ao trabalho em equipe, em que área você notou maior desenvolvimento?'].value_counts()
# Out:
# Com relação ao trabalho em equipe, em que área você notou maior desenvolvimento?
# Gestão do grupo: conseguir que a equipe trabalhasse colaborativamente.              28
# Interação: interagir com a equipe.                                                   8
# Horários: organizar a disponibilidade de tempo dos membros da equipe                 6
# Liderança: decidir quem iria liderar a equipe.                                       5
# Questões culturais: conciliar as diferenças entre as culturas.                       4
# Tempo: pouco tempo para realizar as tarefas.                                         4
# Questões linguísticas: conseguir me comunicar com meus parceiros internacionais.     1
# Tarefas: resolver atividades muito complexas.                                        1
# Name: count, dtype: int64

# %% [markdown]
# Com relação ao trabalho em equipe, o que foi mais desafiador para você?

# %%
sns.countplot(x='Com relação ao trabalho em equipe, o que foi mais desafiador para você?',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('O que foi mais desafiador')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Com relação ao trabalho em equipe, o que foi mais desafiador para você?'].value_counts()
# Out:
# Com relação ao trabalho em equipe, o que foi mais desafiador para você?
# Horários: organizar a disponibilidade de tempo dos membros da equipe                30
# Gestão do grupo: conseguir que a equipe trabalhasse colaborativamente.              14
# Interação: interagir com a equipe.                                                   4
# Questões linguísticas: conseguir me comunicar com meus parceiros internacionais.     3
# Questões culturais: conciliar as diferenças entre as culturas.                       2
# Tempo: pouco tempo para realizar as tarefas.                                         2
# Tarefas: resolver atividades muito complexas.                                        2
# Name: count, dtype: int64

# %% [markdown]
# Aponte os pontos positivos deste PCI.

# %% [markdown]
# FIcar a saber. Com a equipa. Em equipa. Partilhas

# %%
discentes_2s_2023_ipiranga_filtrado['Aponte os pontos positivos deste PCI.'].value_counts()
# Out:
# Aponte os pontos positivos deste PCI.
# Interação com alunos estrangeiros                                                                                                                                                                                                                     1
# Foi uma experiência positiva, bom interagir com colegas de outro país e conhecer suas percepções sobre os temas. Uma experiência enriquecedora.                                                                                                       1
# Trabalhamos em conjunto e tivemos que nos adaptar a realidade de outros estudantes                                                                                                                                                                    1
# ...

# %% [markdown]
# Aponte os pontos a serem melhorados neste PCI.

# %%
discentes_2s_2023_ipiranga_filtrado['Aponte os pontos a serem melhorados neste PCI.'].value_counts()
# Out:
# Aponte os pontos a serem melhorados neste PCI.
# .                                                                                                                                                                                                                                                                                       2
# Horarios                                                                                                                                                                                                                                                                                2
# Comunicação                                                                                                                                                                                                                                                                             2
# ...

# %% [markdown]
# Faça uma autoavaliação do seu desempenho no projeto.

# %%
sns.countplot(x='Faça uma autoavaliação do seu desempenho no projeto.',data=discentes_2s_2023_ipiranga_filtrado)
plt.xticks(rotation=45)
plt.title('Autoavaliação de desempenho')
plt.xlabel('Resposta')
plt.ylabel('Count')
plt.show()

# %%
discentes_2s_2023_ipiranga_filtrado['Faça uma autoavaliação do seu desempenho no projeto.'].value_counts()
# Out:
# Faça uma autoavaliação do seu desempenho no projeto.
# Bom                   29
# Excelente             24
# Poderia ser melhor     2
# Regular                2
# Name: count, dtype: int64

# %% [markdown]
# Filtrando portugueses

# %%
filtro = discentes_2s_2023_ipiranga_filtrado['Aponte os pontos positivos deste PCI.'].str.contains('Ficar a saber|equipa|Partilhas')

# %%
discentes_2s_2023_aveiro = discentes_2s_2023_ipiranga_filtrado[filtro]

# %%
discentes_2s_2023_aveiro
# Out:
#    Quantas vezes você já participou de um PCI?  \
# 34             Uma - este é o meu primeiro PCI
# 43             Uma - este é o meu primeiro PCI
# 45             Uma - este é o meu primeiro PCI
# 49             Uma - este é o meu primeiro PCI
# 50             Uma - este é o meu primeiro PCI
# 51             Uma - este é o meu primeiro PCI
# 54             Uma - este é o meu primeiro PCI
#
#    Recomendaria aos seus colegas participar em um PCI.  \
# 34                              Concordo parcialmente
# 43                                Concordo totalmente
# 45                                Concordo totalmente
# 49                              Concordo parcialmente
# 50                                Concordo totalmente
# 51                              Concordo parcialmente
# 54                              Concordo parcialmente
#
#    Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro  \
# 34                                   Foi em português
# ...

# %%
discentes_2s_2023_aveiro.value_counts().sum()
# Out:
# 7

# %% [markdown]
# Filtrando brasileiros

# %%
filtro_exclusao = ~discentes_2s_2023_ipiranga_filtrado['Aponte os pontos positivos deste PCI.'].str.contains('Ficar a saber|equipa|Partilhas')

# %%
discentes_2s_2023_ipiranga = discentes_2s_2023_ipiranga_filtrado[filtro_exclusao]

# %%
discentes_2s_2023_ipiranga
# Out:
#    Quantas vezes você já participou de um PCI?  \
# 0                                         Duas
# 1              Uma - este é o meu primeiro PCI
# 2                                         Duas
# 3                                         Duas
# 4                                         Duas
# 5                                         Duas
# 6              Uma - este é o meu primeiro PCI
# 7              Uma - este é o meu primeiro PCI
# 8              Uma - este é o meu primeiro PCI
# 9              Uma - este é o meu primeiro PCI
# 10             Uma - este é o meu primeiro PCI
# 11             Uma - este é o meu primeiro PCI
# 12                                        Duas
# 13             Uma - este é o meu primeiro PCI
# 14                                        Duas
# 15                          Três ou mais vezes
# 16                                        Duas
# 17                                        Duas
# 18                                        Duas
# ...

# %%
discentes_2s_2023_ipiranga.value_counts().sum()
# Out:
# 50

# %% [markdown]
# ### Comparações Brasileiros x Portugueses

# %% [markdown]
# Quantas vezes você já participou de um PCI?

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Quantas vezes você já participou de um PCI?', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Quantidade de vezes que participou de um PCI (Brasileiros)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Quantas vezes você já participou de um PCI?', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Quantidade de vezes que participou de um PCI (Portugueses)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Recomendaria aos colegas participar em um PCI

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Recomendaria aos seus colegas participar em um PCI.', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Recomendaria aos colegas participar em um PCI (Brasileiros)')
plt.xlabel(' ')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Recomendaria aos seus colegas participar em um PCI.', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Recomendaria aos colegas participar em um PCI (Portugueses)')
plt.xlabel(' ')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Competência no idioma estrangeiro (Brasileiros)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Competência no idioma estrangeiro (Portugueses)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Chances no mercado de trabalho aumentaram

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Chances no mercado de trabalho aumentaram', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Chances no mercado de trabalho aumentaram (Brasileiros)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Chances no mercado de trabalho aumentaram', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Chances no mercado de trabalho aumentaram (Portugueses)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# PCI aumentou interesse em permanecer no curso até a conclusão

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='PCI aumentou interesse em permanecer no curso até a conclusão', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('PCI aumentou interesse em permanecer no curso (Brasileiros)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='PCI aumentou interesse em permanecer no curso até a conclusão', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('PCI aumentou interesse em permanecer no curso (Portugueses)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Como foi sua interação com seus colegas do grupo brasileiro?

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Como foi sua interação com seus colegas do grupo brasileiro?', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Interação com seus colegas do grupo brasileiro (Brasileiros)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Como foi sua interação com seus colegas do grupo brasileiro?', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Interação com seus colegas do grupo brasileiro (Portugueses)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Interação com seus colegas do grupo estrangeiro

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Como foi sua interação com seus colegas do grupo estrangeiro?', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Interação com seus colegas do grupo estrangeiro (Brasileiros)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Como foi sua interação com seus colegas do grupo estrangeiro?', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Interação com seus colegas do grupo estrangeiro (Portugueses)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Você se dedicou à realização das tarefas do PCI.

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Você se dedicou à realização das tarefas do PCI.', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Se dedicou à realização das tarefas do PCI (Brasileiros)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Você se dedicou à realização das tarefas do PCI.', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Se dedicou à realização das tarefas do PCI (Portugueses)')
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# O grupo brasileiro se dedicou à realização das tarefas do PCI.

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='O grupo brasileiro se dedicou à realização das tarefas do PCI.', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Grupo brasileiro se dedicou à realização das tarefas do PCI (Brasileiros)', fontsize=10)
plt.xlabel('Quantidade')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='O grupo brasileiro se dedicou à realização das tarefas do PCI.', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Grupo brasileiro se dedicou à realização das tarefas do PCI (Portugueses)', fontsize=10)
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# O grupo estrangeiro se dedicou à realização das tarefas do PCI.

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='O grupo estrangeiro se dedicou à realização das tarefas do PCI.', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Grupo estrangeiro se dedicou à realização das tarefas do PCI (Brasileiros)', fontsize=10)
plt.xlabel('Quantidade')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='O grupo estrangeiro se dedicou à realização das tarefas do PCI.', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Grupo estrangeiro se dedicou à realização das tarefas do PCI (Portugueses)', fontsize=10)
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Estava motivado a participar de um PCI antes de ter tido esta experiência

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Estava motivado a participar de um PCI antes de ter tido esta experiência', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Motivado a participar de um PCI antes de ter tido esta experiência (Brasileiros)', fontsize=10)
plt.xlabel('Quantidade')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Estava motivado a participar de um PCI antes de ter tido esta experiência', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Motivado a participar de um PCI antes de ter tido esta experiência (Portugueses)', fontsize=10)
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Em termos de trabalho em equipe com os brasileiros, a experiência foi satisfatória\n

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Em termos de trabalho em equipe com os brasileiros, a experiência foi satisfatória\n', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Trabalho em equipe com os brasileiros foi satisfatório (Brasileiros)', fontsize=10)
plt.xlabel('Quantidade')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Em termos de trabalho em equipe com os brasileiros, a experiência foi satisfatória\n', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Trabalho em equipe com os brasileiros foi satisfatório (Portugueses)', fontsize=10)
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Em termos de trabalho em equipe com os estrangeiros, a experiência foi satisfatória

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Em termos de trabalho em equipe com os estrangeiros, a experiência foi satisfatória', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Trabalho em equipe com os estrangeiros foi satisfatório (Brasileiros)', fontsize=10)
plt.xlabel('Quantidade')
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Em termos de trabalho em equipe com os estrangeiros, a experiência foi satisfatória', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Trabalho em equipe com os estrangeiros foi satisfatório (Portugueses)', fontsize=10)
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Com relação ao trabalho em equipe, em que área você notou maior desenvolvimento?

# %%
plt.figure(figsize=(24, 12))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Com relação ao trabalho em equipe, em que área você notou maior desenvolvimento?', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Área que notou maior desenvolvimento (Brasileiros)', fontsize=10)
plt.xlabel('Quantidade', fontsize=10)
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Com relação ao trabalho em equipe, em que área você notou maior desenvolvimento?', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Área que notou maior desenvolvimento (Portugueses)', fontsize=10)
plt.xlabel('Quantidade', fontsize=10)
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Com relação ao trabalho em equipe, o que foi mais desafiador para você?

# %%
plt.figure(figsize=(24, 12))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Com relação ao trabalho em equipe, o que foi mais desafiador para você?', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Com relação ao trabalho em equipe, o que foi mais desafiador para você? (Brasileiros)', fontsize=10)
plt.xlabel('Quantidade', fontsize=10)
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Com relação ao trabalho em equipe, o que foi mais desafiador para você?', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Com relação ao trabalho em equipe, o que foi mais desafiador para você? (Portugueses)', fontsize=10)
plt.xlabel('Quantidade', fontsize=10)
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Faça uma autoavaliação do seu desempenho no projeto.

# %%
plt.figure(figsize=(12, 6))  # Ajuste o tamanho da figura conforme necessário

# Gráfico para o primeiro DataFrame
plt.subplot(1, 2, 1)  # Cria o primeiro subplot
sns.countplot(x='Faça uma autoavaliação do seu desempenho no projeto.', data=discentes_2s_2023_ipiranga)
plt.xticks(rotation=45)
plt.title('Faça uma autoavaliação do seu desempenho no projeto. (Brasileiros)', fontsize=10)
plt.xlabel('Quantidade', fontsize=10)
plt.ylabel('Count')

# Gráfico para o segundo DataFrame
plt.subplot(1, 2, 2)  # Cria o segundo subplot
sns.countplot(x='Faça uma autoavaliação do seu desempenho no projeto.', data=discentes_2s_2023_aveiro)
plt.xticks(rotation=45)
plt.title('Faça uma autoavaliação do seu desempenho no projeto. (Portugueses)', fontsize=10)
plt.xlabel('Quantidade')
plt.ylabel('Count')

plt.tight_layout()  # Ajusta o espaçamento entre os subplots
plt.show()

# %% [markdown]
# Traço cultural: os brasileiros são mais sinceros

# %% [markdown]
# ## Discentes

# %% [markdown]
# ### discenetes_1s_2022 (Não será utilizado - Não possuí dados nem da Fatec Ipiranga, nem da Fatec Aveiro)

# %%
discentes_1s_2022.head()
# Out:
#    ID          Start time     Completion time  \
# 0   1 2022-09-21 10:44:41 2022-09-21 10:56:06
# 1   2 2022-09-21 10:42:07 2022-09-21 10:56:31
# 2   3 2022-09-21 10:56:28 2022-09-21 11:00:14
# 3   4 2022-09-21 10:52:39 2022-09-21 11:01:30
# 4   5 2022-09-21 10:51:43 2022-09-21 11:03:46
#
#    O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
discentes_1s_2022.shape
# Out:
# (52, 45)

# %%
discentes_1s_2022.isnull().sum()
# Out:
# ID                                                                                                                                                                                                            0
# Start time                                                                                                                                                                                                    0
# Completion time                                                                                                                                                                                               0
# O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?                                                                                                                               52
# ...

# %%
discentes_1s_2022.shape
# Out:
# (52, 45)

# %%
discentes_1s_2022.isna().sum()
# Out:
# ID                                                                                                                                                                                                            0
# Start time                                                                                                                                                                                                    0
# Completion time                                                                                                                                                                                               0
# O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?                                                                                                                               52
# ...

# %%
discentes_1s_2022.columns
# Out:
# Index(['ID', 'Start time', 'Completion time',
#        'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?',
#        'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?2',
#        'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?3',
#        'Em qual período você estuda?',
#        'Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Você participou de um PCI em qual idioma?',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI  aumenta as chances de sucesso no mercado de trabalho", eu',
#        'Quanto à afirmação "A experiência com o PCI aumentou meu interesse em permanecer no curso até a conclusão", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Explique sua resposta à questão anterior.',
# ...

# %%
discentes_1s_2022.drop(discentes_1s_2022.columns[0:10], axis=1, inplace=True)

# %%
# Renomeando a coluna com espaços  e removendo espaços extras
discentes_1s_2022.columns = discentes_1s_2022.columns.str.replace('O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?', 'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?').str.strip()

# %%
discentes_1s_2022.columns
# Out:
# Index(['Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI  aumenta as chances de sucesso no mercado de trabalho", eu',
#        'Quanto à afirmação "A experiência com o PCI aumentou meu interesse em permanecer no curso até a conclusão", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Explique sua resposta à questão anterior.',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'Explique sua resposta à questão anterior.2', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão Oral', 'Gramática',
#        'As instruções sobre os procedimentos estavam claras.',
#        'As etapas de organização do projeto estavam adequadas.',
#        'Os objetivos do projeto estavam claros.',
#        'O tempo para a realização das tarefas foi suficiente.',
#        'O grupo estrangeiro tinha as mesmas informações que o grupo brasileiro.',
# ...

# %%
discentes_1s_2022['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'].value_counts()
# Out:
# O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?
# Fatec Garça e Setsunan University do Japão com profa. Leysiane    31
# Fatec Itaquaquecetuba e SUNY EOP com profa. Paula Pudo            21
# Name: count, dtype: int64

# %% [markdown]
# ### discenetes_1s_2023

# %% [markdown]
#   concertar para não apagar essa coluna quando aplicar o for: :'Com relação ao trabalho em equipe, em que área você notou maior desenvolvimento? ',

# %%
discentes_1s_2023.head()
# Out:
#    ID          Start time     Completion time  \
# 0   1 2023-05-15 13:45:05 2023-05-15 13:52:40
# 1   2 2023-05-15 13:49:22 2023-05-15 14:28:39
# 2   3 2023-05-15 16:09:42 2023-05-15 16:18:22
# 3   4 2023-05-15 16:07:40 2023-05-15 16:20:51
# 4   5 2023-05-15 16:10:29 2023-05-15 16:22:20
#
#   O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?  \
# 0  Fatec São José do Rio Preto com prof. Vera Enc...
# 1  Fatec Bragança Paulista com prof. Vera Encarna...
# 2  Fatec Pompeia com Prof. Antonio Cesar Dall'Eve...
# 3  Fatec Pompéia com prof. Vânia Regina Alves de ...
# 4  Fatec Pompéia com prof. Vânia Regina Alves de ...
#
#   Em qual período você estuda? Quantas vezes você já participou de um PCI?  \
# 0                        Manhã                                        Duas
# 1                        Manhã             Uma - este é o meu primeiro PCI
# 2                        Tarde             Uma - este é o meu primeiro PCI
# ...

# %%
discentes_1s_2023.shape
# Out:
# (741, 60)

# %%
discentes_1s_2023.isnull().sum()
# Out:
# ID                                                                                                                                                                                                             0
# Start time                                                                                                                                                                                                     0
# Completion time                                                                                                                                                                                                0
# O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?                                                                                                                                 0
# ...

# %%
discentes_1s_2023.columns
# Out:
# Index(['ID', 'Start time', 'Completion time',
#        'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?',
#        'Em qual período você estuda?',
#        'Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão Oral', 'Gramática',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI  aumenta as chances de sucesso no mercado de trabalho", eu',
#        'Quanto à afirmação "A experiência com o PCI aumenta meu interesse em permanecer no curso até a conclusão", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Explique sua resposta à questão anterior.',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
# ...

# %%
discentes_1s_2023['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'].value_counts()
# Out:
# O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?
# Fatec Ipiranga com Prof. Patricia Patrício e Aveiro no projeto Comunicação Empresarial e consumo sustentável: uma abordagem                                                                      45
# Fatec Baixada Santista com Prof. Valeria Carneiro da Silva e Ruy Cordeiro Accioly e Uniminuto no projeto Study of AI and VR Applications in Digital Marketing                                    32
# Fatec São Caetano do Sul com Prof. Maria Marcia  Matos Pinto e FSU no projeto Collaborative Online International Learning (COIL) FATEC - FSU COIL Partnership                                    28
# Fatec Araçatuba com Prof. Euclides Teixeira Neto e Luciane Berti Ribeiro e Symbiosis no projeto Transportation Sector & SDGs                                                                     27
# ...

# %%
# Filtro Ipiranga x Aveiro
filtro_resultado = discentes_1s_2023['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'] == 'Fatec Ipiranga com Prof. Patricia Patrício e Aveiro no projeto Comunicação Empresarial e consumo sustentável: uma abordagem'

discentes_1s_2023_filtrado = discentes_1s_2023[filtro_resultado]

# %%
discentes_1s_2023_filtrado.head()
# Out:
#       ID          Start time     Completion time  \
# 236  237 2023-05-26 17:29:44 2023-05-26 17:38:14
# 237  238 2023-05-26 17:49:41 2023-05-26 17:53:18
# 238  239 2023-05-26 19:36:49 2023-05-26 19:44:29
# 239  240 2023-05-26 23:07:27 2023-05-26 23:30:09
# 242  243 2023-05-28 11:43:31 2023-05-28 12:06:11
#
#     O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?  \
# 236  Fatec Ipiranga com Prof. Patricia Patrício e A...
# 237  Fatec Ipiranga com Prof. Patricia Patrício e A...
# 238  Fatec Ipiranga com Prof. Patricia Patrício e A...
# 239  Fatec Ipiranga com Prof. Patricia Patrício e A...
# 242  Fatec Ipiranga com Prof. Patricia Patrício e A...
#
#     Em qual período você estuda? Quantas vezes você já participou de um PCI?  \
# 236                        Noite                                        Duas
# 237                        Noite                                        Duas
# ...

# %%
discentes_1s_2023_filtrado.columns
# Out:
# Index(['ID', 'Start time', 'Completion time',
#        'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?',
#        'Em qual período você estuda?',
#        'Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão Oral', 'Gramática',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI  aumenta as chances de sucesso no mercado de trabalho", eu',
#        'Quanto à afirmação "A experiência com o PCI aumenta meu interesse em permanecer no curso até a conclusão", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Explique sua resposta à questão anterior.',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
# ...

# %%
colunas_para_remover = [coluna for coluna in discentes_1s_2023_filtrado.columns if coluna.startswith('Termo de consentimento')]
discentes_1s_2023_filtrado.drop(columns=colunas_para_remover, inplace=True)
# Out:
# <ipython-input-99-3c341cf01283>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   discentes_1s_2023_filtrado.drop(columns=colunas_para_remover, inplace=True)

# %%
colunas_para_remover = ['ID', 'Start time', 'Completion time', 'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?', 'Em qual período você estuda?', 'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita', 'Leitura', 'Compreensão Oral', 'Gramática', 'As instruções sobre os procedimentos estavam claras.', 'As etapas de organização do projeto estavam adequadas.', 'Os objetivos do projeto estavam claros.', 'O tempo para a realização das tarefas foi suficiente.', 'O grupo estrangeiro tinha as mesmas informações que o grupo brasileiro.', 'O(a) professor(a) dedicou tempo de aula para a resolução de dúvidas.', 'O(a) professor(a) ofereceu ajuda para resolver questões relativas aos PCIs.', 'Quais ferramentas você utilizou para a realização do PCI? (Marque todas as que você utilizou para se comunicar com as equipes e realizar as tarefas propostas)', 'mês_de_inicio', 'mês_de_trmino', 'ano', 'nome_do_PCI', 'nome_da_Fatec', 'nome_da_IES_internacional', 'nome_doa_prof_da_Fatec', 'nome_doa_prof_da_IES_internacional', 'número_de_horas', 'língua_em_que_foi_realizado', 'dia_cert', 'mês_cert', 'mailwhite', 'Filename', 'Status']
discentes_1s_2023_filtrado.drop(columns=colunas_para_remover, inplace=True)
# Out:
# <ipython-input-100-9a95d89d83b3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   discentes_1s_2023_filtrado.drop(columns=colunas_para_remover, inplace=True)

# %%
discentes_1s_2023_filtrado.columns
# Out:
# Index(['Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI  aumenta as chances de sucesso no mercado de trabalho", eu',
#        'Quanto à afirmação "A experiência com o PCI aumenta meu interesse em permanecer no curso até a conclusão", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Explique sua resposta à questão anterior.',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'Explique sua resposta à questão anterior.2',
#        'Você se dedicou à realização das tarefas do PCI.',
#        'O grupo brasileiro se dedicou à realização das tarefas do PCI.',
#        'O grupo estrangeiro se dedicou à realização das tarefas do PCI.',
#        'Você buscou interagir com o grupo brasileiro.',
# ...

# %%
colunas_para_remover = [coluna for coluna in discentes_1s_2023_filtrado.columns if coluna.startswith('Com relação ao trabalho em equipe, o que foi mais desafiador')]
discentes_1s_2023_filtrado.drop(columns=colunas_para_remover, inplace=True)
# Out:
# <ipython-input-102-65609f404099>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   discentes_1s_2023_filtrado.drop(columns=colunas_para_remover, inplace=True)

# %%
discentes_1s_2023_filtrado.columns
# Out:
# Index(['Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI  aumenta as chances de sucesso no mercado de trabalho", eu',
#        'Quanto à afirmação "A experiência com o PCI aumenta meu interesse em permanecer no curso até a conclusão", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Explique sua resposta à questão anterior.',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'Explique sua resposta à questão anterior.2',
#        'Você se dedicou à realização das tarefas do PCI.',
#        'O grupo brasileiro se dedicou à realização das tarefas do PCI.',
#        'O grupo estrangeiro se dedicou à realização das tarefas do PCI.',
#        'Você buscou interagir com o grupo brasileiro.',
# ...

# %%
discentes_1s_2023_filtrado.head()
# Out:
#     Quantas vezes você já participou de um PCI?  \
# 236                                        Duas
# 237                                        Duas
# 238                                        Duas
# 239                                        Duas
# 242                                        Duas
#
#     Recomendaria aos seus colegas participar em um PCI.  \
# 236                                Discordo totalmente
# 237                              Concordo parcialmente
# 238                              Concordo parcialmente
# 239                                Concordo totalmente
# 242                                Discordo totalmente
#
#     Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro  \
# 236                                        Ficou igual
# 237                                        Ficou igual
# 238                                        Ficou igual
# 239                                   Foi em português
# ...

# %% [markdown]
# ## Docentes

# %%
docentes_1s_2022 = pd.read_excel('/content/drive/MyDrive/PCI_Anonimizados/Anonimizados/1s2022 Docentes -Pesquisa de Percepção sobre o Projeto Colaborativo Internacional PCI_CESU (1-99).xlsx')

# %%
docentes_2s_2022 = pd.read_excel('/content/drive/MyDrive/PCI_Anonimizados/Anonimizados/2s2022 Docentes -Pesquisa de Percepção sobre o Projeto Colaborativo Internacional PCI_CESU (1-47).xlsx')

# %% [markdown]
# ### docentes_1s_2022

# %%
docentes_1s_2022.head()
# Out:
#    ID      Hora de início   Hora de conclusão  \
# 0   1 2022-05-31 15:43:45 2022-05-31 16:08:03
# 1   2 2022-05-31 15:45:40 2022-05-31 16:08:15
# 2   3 2022-06-01 17:53:20 2022-06-01 18:09:38
# 3   4 2022-06-01 18:11:11 2022-06-01 18:19:56
# 4   5 2022-06-02 11:40:18 2022-06-02 11:51:46
#
#   Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)  \
# 0               Fatec Cruzeiro - Prof. Waldomiro May
# 1                                     Fatec Cruzeiro
# 2                                        Fatec Bauru
# 3                                        Fatec Garça
# 4                                     Fatec Ipiranga
#
#   Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)  \
# 0  Symbiosis Centre for Management Studies -  Pun...
# 1  Symbiosis Center for Management Studies - Pune...
# 2                               Queens College, CUNY
# 3                                     Wagner College
# ...

# %%
docentes_1s_2022.columns
# Out:
# Index(['ID', 'Hora de início', 'Hora de conclusão',
#        'Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)',
#        'Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)',
#        'Em termos de PCI, esta experiência foi a sua',
#        'Recomendaria aos outros professores de sua Fatec a participar em um PCI?',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão oral',
#        'Com a interação proporcionada pelo PCI, a sua competência em língua estrangeira',
#        'Novas atividades acadêmicas a partir da experiência do parceiro internacional',
#        'Pesquisas em minha área de atuação',
#        'Artigos acadêmicos conjuntamente com meu (minha) parceiro(a)',
#        'Visitas técnicas à IES do parceiro', 'Visitas técnicas à minha Fatec',
#        'A partir da inserção dos PCIs em suas atividades, a interação com seus alunos:',
# ...

# %%
docentes_1s_2022['Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)'].value_counts()
# Out:
# Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)
# Fatec Indaiatuba                                                                                           7
# Fatec Garça                                                                                                6
# Fatec Garça                                                                                                6
# Fatec Praia Grande                                                                                         5
# Fatec Indaiatuba                                                                                           4
# Fatec São Caetano do Sul                                                                                   3
# Fatec Americana                                                                                            3
# Fatec Pompeia                                                                                              3
# ...

# %%
# Remover espaços extras na coluna de interesse
docentes_1s_2022['Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)'] = docentes_1s_2022['Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)'].str.strip()

# Filtrar novamente
filtro_resultado = (docentes_1s_2022['Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)'] == 'Fatec Ipiranga') | (docentes_1s_2022['Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)'] == 'Ipiranga')
docentes_1s_2022_filtrado = docentes_1s_2022[filtro_resultado]

# %%
docentes_1s_2022_filtrado['Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)'].value_counts()
# Out:
# Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)
#  Jamestown Community College    1
# INACAP                          1
# Universidade de Aveiro          1
# Inacap                          1
# Name: count, dtype: int64

# %%
# Remover espaços extras na coluna de interesse
docentes_1s_2022_filtrado.loc[:, 'Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)'] = docentes_1s_2022_filtrado['Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)'].str.strip()

# Filtrar novamente
filtro_resultado = (docentes_1s_2022_filtrado['Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)'] == 'Universidade de Aveiro')
docentes_1s_2022_filtrado2 = docentes_1s_2022_filtrado.loc[filtro_resultado]

# %%
docentes_1s_2022_filtrado2.head()
# Out:
#     ID      Hora de início   Hora de conclusão  \
# 58  59 2022-06-23 19:17:42 2022-06-23 19:28:27
#
#    Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)  \
# 58                                     Fatec Ipiranga
#
#    Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)  \
# 58                             Universidade de Aveiro
#
#    Em termos de PCI, esta experiência foi a sua  \
# 58                                     segunda
#
#    Recomendaria aos outros professores de sua Fatec a participar em um PCI?  \
# 58                                Concordo totalmente
#
#    Você participou de um PCI em qual idioma?                    Fala  \
# 58                                 Português  Foi feito em Português
#
#                    Escrita  ...  \
# 58  Foi feito em Português  ...
#
#    Acredito que a interação entre os grupos mistos (brasileiros e estrangeiros) precise ser melhorada.  \
# ...

# %%
docentes_1s_2022_filtrado2.columns
# Out:
# Index(['ID', 'Hora de início', 'Hora de conclusão',
#        'Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)',
#        'Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)',
#        'Em termos de PCI, esta experiência foi a sua',
#        'Recomendaria aos outros professores de sua Fatec a participar em um PCI?',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão oral',
#        'Com a interação proporcionada pelo PCI, a sua competência em língua estrangeira',
#        'Novas atividades acadêmicas a partir da experiência do parceiro internacional',
#        'Pesquisas em minha área de atuação',
#        'Artigos acadêmicos conjuntamente com meu (minha) parceiro(a)',
#        'Visitas técnicas à IES do parceiro', 'Visitas técnicas à minha Fatec',
#        'A partir da inserção dos PCIs em suas atividades, a interação com seus alunos:',
# ...

# %%
colunas_para_remover = [coluna for coluna in docentes_1s_2022_filtrado2.columns if coluna.startswith('Eu autorizo a divulgação dos dados')]
docentes_1s_2022_filtrado2.drop(columns=colunas_para_remover, inplace=True)
# Out:
# <ipython-input-115-53aa7f12694b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   docentes_1s_2022_filtrado2.drop(columns=colunas_para_remover, inplace=True)

# %%
colunas_para_remover = ['ID', 'Hora de início', 'Hora de conclusão', 'Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)', 'Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)', 'Recomendaria aos outros professores de sua Fatec a participar em um PCI?', 'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita', 'Leitura', 'Compreensão oral', 'Novas atividades acadêmicas a partir da experiência do parceiro internacional', 'Pesquisas em minha área de atuação', 'Artigos acadêmicos conjuntamente com meu (minha) parceiro(a)', 'Visitas técnicas à IES do parceiro', 'Visitas técnicas à minha Fatec', 'As instruções sobre os procedimentos estavam claras.', 'As etapas de organização do projeto estavam adequadas.', 'Os objetivos do projeto estavam claros.', 'Acompanhei todas as etapas do projeto com meus alunos.', 'Todos os objetivos do projeto foram alcançados.', 'Caso você realize um outro PCI, quais ferramentas abaixo são importantes para você (se necessário, pode marcar mais que uma opção)?', 'Os alunos aprenderam a utilizar uma nova ferramenta tecnológica.', 'Os alunos somente utilizaram ferramentas tecnológicas que eles já conheciam.', 'Em termos de expectativa, quais fatores eram/são mais relevantes para você? Assinale as alternativas que correspondem à sua percepção.']
docentes_1s_2022_filtrado2.drop(columns=colunas_para_remover, inplace=True)
# Out:
# <ipython-input-116-e1ed185959ed>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   docentes_1s_2022_filtrado2.drop(columns=colunas_para_remover, inplace=True)

# %%
docentes_1s_2022_filtrado2.columns
# Out:
# Index(['Em termos de PCI, esta experiência foi a sua',
#        'Com a interação proporcionada pelo PCI, a sua competência em língua estrangeira',
#        'A partir da inserção dos PCIs em suas atividades, a interação com seus alunos:',
#        'Os alunos brasileiros se dedicaram à realização das tarefas do projeto.',
#        'Como foi sua interação com seu(sua) parceiro(a) internacional?',
#        'Os alunos estrangeiros se dedicaram à realização das tarefas do projeto.',
#        'Busquei interagir com meu parceiro internacional além do proposto pelo projeto.',
#        'Por favor, descreva brevemente sua impressão da interação com o parceiro internacional\n',
#        'Em sua opinião,',
#        'A fase de "quebra-gelo" foi o momento em que os alunos mais participaram.',
#        'A fase de "conhecimento do país estrangeiro" foi o momento em que os alunos mais participaram.',
# ...

# %% [markdown]
# ### docentes_2s_2022

# %%
docentes_2s_2022.head()
# Out:
#    ID      Hora de início   Hora de conclusão  \
# 0   1 2022-11-28 15:58:35 2022-11-28 16:12:02
# 1   2 2022-11-28 15:59:43 2022-11-28 16:14:33
# 2   3 2022-11-28 16:23:19 2022-11-28 16:37:22
# 3   4 2022-11-28 16:16:45 2022-11-28 16:40:35
# 4   5 2022-11-28 16:06:06 2022-11-28 16:48:27
#
#   Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)  \
# 0                                Fatec Guaratingueta
# 1                          Fatec de Itaquaquecetuba
# 2                                   Fatec Araçatuba
# 3                                      Fatec Marília
# 4                                    Fatec Rio Preto
#
#   Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)  \
# 0                                         UNIMINUTO
# 1                     Universidad de Monterrey/ UDEM
# 2                              Symbiosis University
# 3                           Universidad de Monterrey
# ...

# %%
docentes_2s_2022.columns
# Out:
# Index(['ID', 'Hora de início', 'Hora de conclusão',
#        'Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)',
#        'Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)',
#        'Em termos de PCI, esta experiência foi a sua',
#        'Recomendaria aos outros professores de sua Fatec a participar em um PCI?',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão oral',
#        'Com a interação proporcionada pelo PCI, a sua competência em língua estrangeira',
#        'Novas atividades acadêmicas a partir da experiência do parceiro internacional',
#        'Pesquisas em minha área de atuação',
#        'Artigos acadêmicos conjuntamente com meu (minha) parceiro(a)',
#        'Visitas técnicas à IES do parceiro', 'Visitas técnicas à minha Fatec',
#        'A partir da inserção dos PCIs em suas atividades, a interação com seus alunos:',
# ...

# %%
docentes_2s_2022['Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)'].value_counts()
# Out:
# Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)
# Fatec Americana                                  4
# Guaratinguetá                                    2
# Fatec Ipiranga                                   2
# Fatec Garça                                      2
# Fatec de Jaboticabal                             2
# Fatec Indaiatuba                                 2
# Fatec Catanduva                                  2
# Fatec Pindamonhangaba                            1
# Fatec Campinas e Fatec Americana                 1
# Fatec Piracicaba                                 1
# Fatec Carapicuiba                                1
# Fatec Ferraz de Vasconcelos                      1
# Fatec Guaratingueta                              1
# Fatec Mogi das Cruzes                            1
# Fatec Indaiatuba                                 1
# Fatec Itaquaquecetuba e Fatec Mogi das Cruzes    1
# Fatec Praia Grande                               1
# ...

# %%
# Remover espaços extras na coluna de interesse
docentes_2s_2022['Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)'] = docentes_2s_2022['Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)'].str.strip()

# Filtrar novamente
filtro_resultado = (docentes_2s_2022['Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)'] == 'Fatec Ipiranga') | (docentes_2s_2022['Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)'] == 'FATEC Ipiranga')
docentes_2s_2022_filtrado = docentes_2s_2022[filtro_resultado]

# %%
docentes_2s_2022_filtrado['Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)'].value_counts()
# Out:
# Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)
# Colegio de Estudios Superiores de Administración (CESA)    1
# Jamestown Community College                                1
# Universidade de Aveiro                                     1
# Name: count, dtype: int64

# %%
# Remover espaços extras na coluna de interesse
docentes_2s_2022_filtrado.loc[:, 'Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)'] = docentes_2s_2022_filtrado['Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)'].str.strip()

# Filtrar novamente
filtro_resultado = (docentes_2s_2022_filtrado['Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)'] == 'Universidade de Aveiro')
docentes_2s_2022_filtrado2 = docentes_2s_2022_filtrado.loc[filtro_resultado]

# %%
docentes_2s_2022_filtrado2.head()
# Out:
#     ID      Hora de início   Hora de conclusão  \
# 32  33 2022-12-12 15:50:24 2022-12-12 15:55:06
#
#    Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)  \
# 32                                     Fatec Ipiranga
#
#    Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)  \
# 32                             Universidade de Aveiro
#
#    Em termos de PCI, esta experiência foi a sua  \
# 32                             terceira ou mais
#
#    Recomendaria aos outros professores de sua Fatec a participar em um PCI?  \
# 32                                Concordo totalmente
#
#    Você participou de um PCI em qual idioma?                    Fala  \
# 32                                 Português  Foi feito em Português
#
#                    Escrita  ...  \
# 32  Foi feito em Português  ...
#
#    Acredito que a interação entre os grupos mistos (brasileiros e estrangeiros) precise ser melhorada.  \
# ...

# %%
docentes_2s_2022_filtrado2.columns
# Out:
# Index(['ID', 'Hora de início', 'Hora de conclusão',
#        'Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)',
#        'Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)',
#        'Em termos de PCI, esta experiência foi a sua',
#        'Recomendaria aos outros professores de sua Fatec a participar em um PCI?',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão oral',
#        'Com a interação proporcionada pelo PCI, a sua competência em língua estrangeira',
#        'Novas atividades acadêmicas a partir da experiência do parceiro internacional',
#        'Pesquisas em minha área de atuação',
#        'Artigos acadêmicos conjuntamente com meu (minha) parceiro(a)',
#        'Visitas técnicas à IES do parceiro', 'Visitas técnicas à minha Fatec',
#        'A partir da inserção dos PCIs em suas atividades, a interação com seus alunos:',
# ...

# %%
colunas_para_remover = [coluna for coluna in docentes_2s_2022_filtrado.columns if coluna.startswith('Termo de consentimento')]
docentes_2s_2022_filtrado.drop(columns=colunas_para_remover, inplace=True)
# Out:
# <ipython-input-126-ec7858b6558a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   docentes_2s_2022_filtrado.drop(columns=colunas_para_remover, inplace=True)

# %%
docentes_2s_2022_filtrado.columns
# Out:
# Index(['ID', 'Hora de início', 'Hora de conclusão',
#        'Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)',
#        'Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)',
#        'Em termos de PCI, esta experiência foi a sua',
#        'Recomendaria aos outros professores de sua Fatec a participar em um PCI?',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão oral',
#        'Com a interação proporcionada pelo PCI, a sua competência em língua estrangeira',
#        'Novas atividades acadêmicas a partir da experiência do parceiro internacional',
#        'Pesquisas em minha área de atuação',
#        'Artigos acadêmicos conjuntamente com meu (minha) parceiro(a)',
#        'Visitas técnicas à IES do parceiro', 'Visitas técnicas à minha Fatec',
#        'A partir da inserção dos PCIs em suas atividades, a interação com seus alunos:',
# ...

# %%
colunas_para_remover = ['ID', 'Hora de início', 'Hora de conclusão', 'Em qual Fatec o PCI foi desenvolvido? (Ex. Fatec Indaiatuba, Fatec Baixada Santista)', 'Qual é o nome da instituição internacional parceira? (Ex. Tianjin Normal University)', 'Recomendaria aos outros professores de sua Fatec a participar em um PCI?', 'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita', 'Leitura', 'Compreensão oral', 'Novas atividades acadêmicas a partir da experiência do parceiro internacional', 'Pesquisas em minha área de atuação', 'Artigos acadêmicos conjuntamente com meu (minha) parceiro(a)', 'Visitas técnicas à IES do parceiro', 'Visitas técnicas à minha Fatec', 'As instruções sobre os procedimentos estavam claras.', 'As etapas de organização do projeto estavam adequadas.', 'Os objetivos do projeto estavam claros.', 'Acompanhei todas as etapas do projeto com meus alunos.', 'Todos os objetivos do projeto foram alcançados.', 'Em sua opinião,', 'Caso você realize um outro PCI, quais ferramentas abaixo são importantes para você (se necessário, pode marcar mais que uma opção)?', 'Os alunos aprenderam a utilizar uma nova ferramenta tecnológica.', 'Os alunos somente utilizaram ferramentas tecnológicas que eles já conheciam.', 'Em termos de expectativa, quais fatores eram/são mais relevantes para você? Assinale as alternativas que correspondem à sua percepção.']
docentes_2s_2022_filtrado.drop(columns=colunas_para_remover, inplace=True)
# Out:
# <ipython-input-128-9e66211ebfd4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   docentes_2s_2022_filtrado.drop(columns=colunas_para_remover, inplace=True)

# %%
docentes_2s_2022_filtrado.columns
# Out:
# Index(['Em termos de PCI, esta experiência foi a sua',
#        'Com a interação proporcionada pelo PCI, a sua competência em língua estrangeira',
#        'A partir da inserção dos PCIs em suas atividades, a interação com seus alunos:',
#        'Os alunos brasileiros se dedicaram à realização das tarefas do projeto.',
#        'Como foi sua interação com seu(sua) parceiro(a) internacional?',
#        'Os alunos estrangeiros se dedicaram à realização das tarefas do projeto.',
#        'Busquei interagir com meu parceiro internacional além do proposto pelo projeto.',
#        'Por favor, descreva brevemente sua impressão da interação com o parceiro internacional\n',
#        'A fase de "quebra-gelo" foi o momento em que os alunos mais participaram.',
#        'A fase de "conhecimento do país estrangeiro" foi o momento em que os alunos mais participaram.',
#        'A fase de "desenvolvimento do tema do projeto" foi o momento em que os alunos mais participaram.',
# ...

# %% [markdown]
# ## Pesquisas

# %%
pesquisa_1s_2022_cesu = pd.read_excel('/content/drive/MyDrive/PCI_Anonimizados/Anonimizados/Pesquisa de Percepção sobre o PCI – Cesu Discentes - 1s2022.xlsx')

# %%
pesquisa_2s_2021_cesu = pd.read_excel('/content/drive/MyDrive/PCI_Anonimizados/Anonimizados/Pesquisa de Percepção sobre o PCI – Cesu Discentes - 2s2021.xlsx')

# %%
xls = pd.ExcelFile('/content/drive/MyDrive/PCI_Anonimizados/Anonimizados/Pesquisa de Percepção sobre o Projeto Colaborativo Internacional – CESU Discentes - 1s2021.xlsx')
pesquisa_1s_2021_discentes = xls.parse(sheet_name='Form1')

# %%
pesquisa_2s_2020_discentes = pd.read_excel('/content/drive/MyDrive/PCI_Anonimizados/Anonimizados/Pesquisa de Percepção sobre o Projeto Colaborativo Internacional – CESUDiscentes-2S2020(1-387).xlsx')

# %% [markdown]
# ### pesquisa_1s_2022_cesu

# %%
pesquisa_1s_2022_cesu.head()
# Out:
#    ID          Start time     Completion time  \
# 0   1 2022-05-20 16:03:30 2022-05-20 16:08:50
# 1   2 2022-05-20 16:02:55 2022-05-20 16:10:38
# 2   3 2022-05-20 16:05:25 2022-05-20 16:13:16
# 3   4 2022-05-20 16:07:13 2022-05-20 16:13:32
# 4   5 2022-05-20 16:12:40 2022-05-20 16:17:27
#
#   O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?  \
# 0  Fatec Ferraz de Vasconcelos e Tianjin (China) ...
# 1  Fatec Ferraz de Vasconcelos e Tianjin (China) ...
# 2  Fatec Ferraz de Vasconcelos e Tianjin (China) ...
# 3  Fatec Garça e Queens College CUNY (EUA) com a ...
# 4  Fatec Ferraz de Vasconcelos e Tianjin (China) ...
#
#   Em qual período você estuda? Quantas vezes você já participou de um PCI?  \
# 0                        Noite             Uma - este é o meu primeiro PCI
# 1                        Noite             Uma - este é o meu primeiro PCI
# 2                        Noite             Uma - este é o meu primeiro PCI
# ...

# %%
pesquisa_1s_2022_cesu.columns
# Out:
# Index(['ID', 'Start time', 'Completion time',
#        'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?',
#        'Em qual período você estuda?',
#        'Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão Oral', 'Gramática',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI aumentou meu interesse em permanecer no curso até a conclusão", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'As instruções sobre os procedimentos estavam claras.',
#        'As etapas de organização do projeto estavam adequadas.',
#        'Os objetivos do projeto estavam claros.',
# ...

# %%
pd.set_option("display.max_rows", None)
pesquisa_1s_2022_cesu['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'].value_counts()
# Out:
# O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?
# Fatec Itaquaquecetuba e Symbiosis  (Índia) com o prof. Ricardo Henrique Trovão Rego                         44
# Fatec Mogi das Cruzes e Sebrae / Tianjin (China) com a profa. Neusa Haruka Sezaki Gritti                    44
# Fatec Cruzeiro e Symbiosis (Índia) com as profas. Luciana Almeida Maia e Luciani Gomes Alvareli             30
# Fatec Americana e Suny Nassau (EUA) com o prof. Carlos Moreira                                              30
# Fatec Franca e Tianjin (China) com a profa. Marcia Helena Venancio                                          28
# Fatec Guaratinguetá e UNIMINUTO  (Colômbia) com as profas. Vanessa Gatto e Regiane Camargo                  27
# Fatec Garça e Queens College CUNY (EUA) com a profa. Leysiane Pazini                                        25
# Fatec Ferraz de Vasconcelos e Tianjin (China) com a profa. Margarete Castilho                               25
# ...

# %%
# Remover espaços extras na coluna de interesse
pesquisa_1s_2022_cesu['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'] = pesquisa_1s_2022_cesu['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'].str.strip()

# Filtrar novamente
filtro_resultado = (pesquisa_1s_2022_cesu['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'] == 'Fatec Ipiranga e Aveiro (Portugal) com a profa. Patrícia Sales Patricio')
pesquisa_1s_2022_cesu_filtrado = pesquisa_1s_2022_cesu[filtro_resultado]

# %%
pesquisa_1s_2022_cesu_filtrado.columns
# Out:
# Index(['ID', 'Start time', 'Completion time',
#        'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?',
#        'Em qual período você estuda?',
#        'Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão Oral', 'Gramática',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI aumentou meu interesse em permanecer no curso até a conclusão", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'As instruções sobre os procedimentos estavam claras.',
#        'As etapas de organização do projeto estavam adequadas.',
#        'Os objetivos do projeto estavam claros.',
# ...

# %%
colunas_para_remover = ['ID', 'Start time', 'Completion time', 'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?', 'Em qual período você estuda?', 'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita', 'Leitura', 'Compreensão Oral', 'Gramática', 'As instruções sobre os procedimentos estavam claras.', 'As etapas de organização do projeto estavam adequadas.', 'Os objetivos do projeto estavam claros.', 'O tempo para a realização das tarefas foi suficiente.', 'O grupo estrangeiro tinha as mesmas informações que o grupo brasileiro.', 'O(a) professor(a) dedicou tempo de aula para a resolução de dúvidas.', 'O(a) professor(a) ofereceu ajuda para resolver questões relativas aos PCIs.', 'Quais ferramentas você utilizou para a realização do PCI? (Marque todas as que você utilizou para se comunicar com as equipes e realizar as tarefas propostas)', 'Faça uma autoavaliação do seu desempenho no projeto.', 'Explique sua resposta à questão anterior.', 'Explique sua resposta à questão anterior.2', 'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?2', 'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?3']
pesquisa_1s_2022_cesu_filtrado.drop(columns=colunas_para_remover, inplace=True)
# Out:
# <ipython-input-139-b0782dee4396>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pesquisa_1s_2022_cesu_filtrado.drop(columns=colunas_para_remover, inplace=True)

# %%
pesquisa_1s_2022_cesu_filtrado.columns
# Out:
# Index(['Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI aumentou meu interesse em permanecer no curso até a conclusão", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'Você se dedicou à realização das tarefas do PCI.',
#        'O grupo brasileiro se dedicou à realização das tarefas do PCI.',
#        'O grupo estrangeiro se dedicou à realização das tarefas do PCI.',
#        'Você buscou interagir com o grupo brasileiro.',
#        'Você buscou interagir com o grupo estrangeiro.',
#        'Aponte os pontos positivos deste PCI.',
#        'Aponte os pontos a serem melhorados neste PCI.',
# ...

# %% [markdown]
# ### pesquisa_2s_2021_cesu

# %%
pesquisa_2s_2021_cesu.head()
# Out:
#     ID          Start time     Completion time  \
# 0  475 2021-12-16 16:54:17 2021-12-16 17:11:09
# 1  487 2021-12-16 18:32:38 2021-12-16 18:42:16
# 2  556 2022-01-04 19:12:43 2022-01-04 19:48:02
# 3  515 2021-12-17 14:59:28 2021-12-17 15:10:54
# 4  488 2021-12-16 18:40:58 2021-12-16 18:50:31
#
#   O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?  \
# 0  Fatec Americana e FSU (EUA) com o prof. Carlos...
# 1  Fatec Americana e FSU (EUA) com o prof. Carlos...
# 2  Fatec Americana e FSU (EUA) com o prof. Carlos...
# 3  Fatec Americana e FSU (EUA) com o prof. Carlos...
# 4  Fatec Americana e FSU (EUA) com o prof. Carlos...
#
#   Em qual período você estuda? Quantas vezes você já participou de um PCI?  \
# 0                        Noite             Uma - este é o meu primeiro PCI
# 1                        Noite             Uma - este é o meu primeiro PCI
# 2                        Noite             Uma - este é o meu primeiro PCI
# ...

# %%
pesquisa_2s_2021_cesu.columns
# Out:
# Index(['ID', 'Start time', 'Completion time',
#        'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?',
#        'Em qual período você estuda?',
#        'Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão Oral', 'Gramática',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI melhora o desempenho acadêmico e aumenta as chances de sucesso no mercado de trabalho", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'As instruções sobre os procedimentos estavam claras.',
#        'As etapas de organização do projeto estavam adequadas.',
#        'Os objetivos do projeto estavam claros.',
# ...

# %%
pesquisa_2s_2021_cesu['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'].value_counts()
# Out:
# O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?
# Fatec Guaratinguetá e UNIMINUTO (Colômbia) com a prof. Regiane                   36
# Fatec Guaratinguetá e SUNY EOP Delhi (EUA) com a prof. Patricia Januária         34
# Fatec Mogi das Cruzes e Sebrae Tianjin (China) com a prof. Neusa Haruka          32
# Fatec Itaquaquecetuba e Symbiosis (Índia) com o prof. Ricardo Trovão             29
# Fatec Americana e Nassau (EUA) com o prof. Carlos Moreira                        28
# Fatec Ipiranga e Universidade de Aveiro (Portugal) com professora Patrícia       27
# Fatec Americana e Symbiosis (Índia) com o prof. Ricardo Pompeu                   24
# Fatec São Caetano Sul e FSU (USA) com a prof. Maria Marcia                       23
# Fatec São Caetano do Sul e DUT (África do Sul) com a prof. Aline                 23
# Fatec Ipiranga e UNIMINUTO (Colômbia) com os prof. Lelia e Odenildo              23
# ...

# %%
# Remover espaços extras na coluna de interesse
pesquisa_2s_2021_cesu['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'] = pesquisa_2s_2021_cesu['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'].str.strip()

# Filtrar novamente
filtro_resultado = (pesquisa_2s_2021_cesu['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'] == 'Fatec Ipiranga e Universidade de Aveiro (Portugal) com professora Patrícia')
pesquisa_2s_2021_cesu_filtrado = pesquisa_2s_2021_cesu[filtro_resultado]

# %%
pesquisa_2s_2021_cesu_filtrado.columns
# Out:
# Index(['ID', 'Start time', 'Completion time',
#        'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?',
#        'Em qual período você estuda?',
#        'Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão Oral', 'Gramática',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI melhora o desempenho acadêmico e aumenta as chances de sucesso no mercado de trabalho", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'As instruções sobre os procedimentos estavam claras.',
#        'As etapas de organização do projeto estavam adequadas.',
#        'Os objetivos do projeto estavam claros.',
# ...

# %%
colunas_para_remover = ['ID', 'Start time', 'Completion time', 'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?', 'Em qual período você estuda?', 'Recomendaria aos seus colegas participar em um PCI.', 'Você participou de um PCI em qual idioma?', 'Fala', 'Escrita', 'Leitura', 'Compreensão Oral', 'Gramática', 'As instruções sobre os procedimentos estavam claras.', 'As etapas de organização do projeto estavam adequadas.', 'Os objetivos do projeto estavam claros.', 'O tempo para a realização das tarefas foi suficiente.', 'O grupo estrangeiro tinha as mesmas informações que o grupo brasileiro.', 'O(a) professor(a) dedicou tempo de aula para a resolução de dúvidas.', 'O(a) professor(a) ofereceu ajuda para resolver questões relativas aos PCIs.', 'Quais ferramentas você utilizou para a realização do PCI? (Marque todas as que você utilizou para se comunicar com as equipes e realizar as tarefas propostas)', 'Faça uma autoavaliação do seu desempenho no projeto.', 'Justifique sua resposta à questão anterior.']
pesquisa_2s_2021_cesu_filtrado.drop(columns=colunas_para_remover, inplace=True)
# Out:
# <ipython-input-146-dded65b5bf09>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pesquisa_2s_2021_cesu_filtrado.drop(columns=colunas_para_remover, inplace=True)

# %%
pesquisa_2s_2021_cesu_filtrado.columns
# Out:
# Index(['Quantas vezes você já participou de um PCI?',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'Quanto à afirmação "A experiência com o PCI melhora o desempenho acadêmico e aumenta as chances de sucesso no mercado de trabalho", eu',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'Você se dedicou à realização das tarefas do PCI.',
#        'O grupo brasileiro se dedicou à realização das tarefas do PCI.',
#        'O grupo estrangeiro se dedicou à realização das tarefas do PCI.',
#        'Você buscou interagir com o grupo brasileiro.',
#        'Você buscou interagir com o grupo estrangeiro.',
#        'Aponte os pontos positivos deste PCI.',
#        'Aponte os pontos a serem melhorados neste PCI.',
# ...

# %% [markdown]
# ### pesquisa_1s_2021_discentes (Não será utilizado - Não possuí dados da Fatec Aveiro)

# %%
pesquisa_1s_2021_discentes.head()
# Out:
#    ID          Start time     Completion time  \
# 0   2 2021-05-04 20:32:29 2021-05-04 20:37:26
# 1   3 2021-05-04 20:30:56 2021-05-04 20:38:47
# 2   4 2021-05-04 20:33:56 2021-05-04 20:39:07
# 3   5 2021-05-04 20:33:01 2021-05-04 20:39:14
# 4   6 2021-05-04 20:32:11 2021-05-04 20:41:10
#
#   O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?  \
# 0  Fatec Americana e Florida State University com...
# 1  Fatec Americana e Florida State University com...
# 2  Fatec Americana e Florida State University com...
# 3  Fatec Americana e Florida State University com...
# 4  Fatec Americana e Florida State University com...
#
#    Qual o nome do(a) professor(a) responsável pelo Projeto Colaborativo Internacional (PCI)? Caso haja mais de um professor(a), por favor, marque o nome de todos  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# ...

# %%
pesquisa_1s_2021_discentes.columns
# Out:
# Index(['ID', 'Start time', 'Completion time',
#        'O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?',
#        'Qual o nome do(a) professor(a) responsável pelo Projeto Colaborativo Internacional (PCI)? Caso haja mais de um professor(a), por favor, marque o nome de todos',
#        'Em qual período você estuda?',
#        'Quantas vezes você já participou de um PCI?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Você participou de um PCI em qual idioma?',
#        'Como você descreveria sua proficiência no idioma estrangeiro relação à',
#        'Question', 'Fala', 'Escrita', 'Leitura', 'Compreensão Oral',
#        'Gramática', 'Fala2', 'Escrita2', 'Leitura2', 'Compreensão Oral2',
#        'Gramática2',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'A experiência com o PCI melhora o desempenho acadêmico e aumenta as chances de sucesso no mercado de trabalho.',
# ...

# %%
pesquisa_1s_2021_discentes['O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?'].value_counts()
# Out:
# O seu projeto de PCI ocorreu em qual Fatec e com qual instituição estrangeira?
# Fatec Piracicaba e Tianjin Normal University com a profa Mara                                        39
# Fatec Indaiatuba e DePaul University com os profs Ricardo, Renata e Talita                           34
# Fatec Garça e Wagner Community College com os profs. Camila e Antonio Cesar                          31
# Fatec Americana e Florida State University com o prof. Carlos Augusto                                28
# Fatec Baixada Santista e INACAP com o prof. Thames                                                   28
# Fatec Indaiatuba e Instituto Politécnico de Viseu com os profs. Ricardo e Viviane                    28
# Fatec Indaiatuba e Universidad Nacional de Salta com os profs. Ricardo, Renata e Luciana             27
# Fatec Guaratinguetá e UNIMINUTO com a profa Regiane                                                  26
# ...

# %% [markdown]
# ### pesquisa_2s_2020_discentes (Não será utilizado - Não possuí dados da Fatec Aveiro)

# %%
pesquisa_2s_2020_discentes.head()
# Out:
#    ID      Hora de início   Hora de conclusão Qual é a sua Fatec?  \
# 0   3 2020-11-20 20:33:20 2020-11-20 20:38:16        Fatec SEBRAE
# 1   4 2020-11-20 20:39:19 2020-11-20 20:48:54        Fatec Sebrae
# 2   5 2020-11-20 20:46:13 2020-11-20 20:52:08        Fatec SEBRAE
# 3   6 2020-11-20 20:51:17 2020-11-20 20:55:40        Fatec Sebrae
# 4   7 2020-11-20 20:51:00 2020-11-20 20:59:27        Fatec Sebrae
#
#   Qual o nome do(a) professor(a) responsável pelo Projeto Colaborativo Internacional (PCI)?  \
# 0                                       Neuza Haruka
# 1                                       Neusa Haruka
# 2                                       Neusa Haruka
# 3                                      Neusa Haruka
# 4                                       Neusa Haruka
#
#   Qual é o nome da disciplina em que você participou do PCI?  \
# 0                                           Inglês V
# 1                                           Inglês V
# ...

# %%
pesquisa_2s_2020_discentes.columns
# Out:
# Index(['ID', 'Hora de início', 'Hora de conclusão', 'Qual é a sua Fatec?',
#        'Qual o nome do(a) professor(a) responsável pelo Projeto Colaborativo Internacional (PCI)?',
#        'Qual é o nome da disciplina em que você participou do PCI?',
#        'Você estuda no período',
#        'Este é o primeiro PCI do qual você participa?',
#        'Recomendaria aos seus colegas participar em um PCI.',
#        'Você participou de um PCI em que idioma?', 'Fala', 'Escrita',
#        'Leitura', 'Compreensão', 'Gramática',
#        'Com a interação proporcionada pelo PCI, a sua competência no idioma estrangeiro',
#        'A experiência com o PCI melhora o desempenho acadêmico e aumenta as chances de sucesso no mercado de trabalho.',
#        'Como foi sua interação com seus colegas do grupo brasileiro?',
#        'Como foi sua interação com seus colegas do grupo estrangeiro?',
#        'As instruções sobre os procedimentos estavam claras.',
# ...

# %%
pesquisa_2s_2020_discentes['Qual é a sua Fatec?'].value_counts()
# Out:
# Qual é a sua Fatec?
# Fatec Americana                                                                    20
# Americana                                                                          19
# Fatec Bauru                                                                        14
# Fatec Sebrae                                                                       12
# Faculdade de Tecnologia de Americana Ministro Ralph Biasi                          10
# Fatec Americana                                                                     8
# Fatec Rio Preto                                                                     8
# Itaquaquecetuba                                                                     8
# Fatec Ipiranga                                                                      7
# Fatec Itaquaquecetuba                                                               7
# Fatec Praia Grande                                                                  7
# ...

# %%
# Remover espaços extras na coluna de interesse
pesquisa_2s_2020_discentes['Qual é a sua Fatec?'] = pesquisa_2s_2020_discentes['Qual é a sua Fatec?'].str.strip()

# Filtrar novamente
filtro_resultado = (pesquisa_2s_2020_discentes['Qual é a sua Fatec?'] == 'Fatec Ipiranga') | (pesquisa_2s_2020_discentes['Qual é a sua Fatec?'] == 'FATEC Ipiranga') | (pesquisa_2s_2020_discentes['Qual é a sua Fatec?'] == 'Fatec - Ipiranga') | (pesquisa_2s_2020_discentes['Qual é a sua Fatec?'] == 'Fatec Ipiranga- Pastor Enéas Tognini') | (pesquisa_2s_2020_discentes['Qual é a sua Fatec?'] == 'Fatec Ipiranga - Pastor Enéas Tognini') | (pesquisa_2s_2020_discentes['Qual é a sua Fatec?'] == 'Ipiranga') | (pesquisa_2s_2020_discentes['Qual é a sua Fatec?'] == 'Ipiranga') | (pesquisa_2s_2020_discentes['Qual é a sua Fatec?'] == 'IPIRANGA')
pesquisa_2s_2020_discentes_filtrado = pesquisa_2s_2020_discentes[filtro_resultado]

# %%
pesquisa_2s_2020_discentes_filtrado.head()
# Out:
#     ID      Hora de início   Hora de conclusão  \
# 8   11 2020-11-21 00:56:03 2020-11-21 01:13:34
# 20  23 2020-11-22 21:46:19 2020-11-22 22:12:47
# 21  24 2020-11-23 09:20:47 2020-11-23 09:25:06
# 22  25 2020-11-23 09:24:27 2020-11-23 09:35:11
# 29  32 2020-11-23 19:34:39 2020-11-23 19:40:39
#
#                      Qual é a sua Fatec?  \
# 8                         Fatec Ipiranga
# 20                        Fatec Ipiranga
# 21                              IPIRANGA
# 22  Fatec Ipiranga- Pastor Enéas Tognini
# 29                              Ipiranga
#
#    Qual o nome do(a) professor(a) responsável pelo Projeto Colaborativo Internacional (PCI)?  \
# 8                           José Carlos Barbosa Lopes
# 20                          José Carlos Barbosa Lopes
# 21                          José Carlos Barbosa Lopes
# 22                         José Carlos Barbosa Lopes
# 29                          Jose Carlos Barbosa Lopes
#
# ...

# %%
pesquisa_2s_2020_discentes_filtrado['Qual o nome do(a) professor(a) responsável pelo Projeto Colaborativo Internacional (PCI)?']
# Out:
# 8       José Carlos Barbosa Lopes
# 20      José Carlos Barbosa Lopes
# 21      José Carlos Barbosa Lopes
# 22     José Carlos Barbosa Lopes
# 29      Jose Carlos Barbosa Lopes
# 45      José Carlos Barbosa Lopes
# 46      José Carlos Barbosa Lopes
# 127     José Carlos Barbosa Lopes
# 211     Jose Carlos Barbosa Lopes
# 212     José Carlos Barbosa Lopes
# 228     José carlos Barbosa Lopes
# 296     José Carlos Barbosa Lopes
# 297                         José
# 298     José Carlos Barbosa Lopes
# 299     José Carlos Barbosa Lopes
# 305           José Carlos Barbosa
# 337     José Carlos Barbosa Lopes
# 340     Jose Carlos Barbosa Lopes
# 363     JOSÉ CARLOS BARBOSA LOPES
# Name: Qual o nome do(a) professor(a) responsável pelo Projeto Colaborativo Internacional (PCI)?, dtype: object
